# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
weather_api_key
# Out:
# 'cdb29755a41896e8d3ed0e60a4cfbfe8'

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
subset_cities = cities[:10]
subset_cities
# Out:
# ['port-aux-francais',
#  'kodiak',
#  'bilibino',
#  'nicoya',
#  'waitangi',
#  'san patricio',
#  'iqaluit',
#  'adamstown',
#  'mezhdurechensk',
#  'tolanaro']

# %%
url = "https://api.openweathermap.org/data/2.5/weather"
city_url = url + "?q=" + subset_cities[2] + "&APPID=" + weather_api_key
res = requests.get(city_url)
res
# Out:
# <Response [200]>

# %%
res.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "?q=" + city 
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url + "&APPID=" + weather_api_key)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | bilibino
# Processing Record 4 of Set 1 | nicoya
# Processing Record 5 of Set 1 | waitangi
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | adamstown
# Processing Record 9 of Set 1 | mezhdurechensk
# Processing Record 10 of Set 1 | tolanaro
# Processing Record 11 of Set 1 | kenai
# Processing Record 12 of Set 1 | korla
# Processing Record 13 of Set 1 | constantia
# Processing Record 14 of Set 1 | bakanas
# Processing Record 15 of Set 1 | bel ombre
# Processing Record 16 of Set 1 | newman
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | sosnovo-ozerskoye
# Processing Record 19 of Set 1 | invercargill
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | sanctuary point
# Processing Record 22 of Set 1 | college
# Processing Record 23 of Set 1 | pipri
# Processing Record 24 of Set 1 | port allen
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | olonkinbyen
# Processing Record 27 of Set 1 | stanley
# Processing Record 28 of Set 1 | nikolayevsk-on-amure
# Processing Record 29 of Set 1 | hasaki
# Processing Record 30 of Set 1 | edinburgh of the seven seas
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | porto torres
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | papatowai
# Processing Record 35 of Set 1 | blackmans bay
# Processing Record 36 of Set 1 | happy valley-goose bay
# Processing Record 37 of Set 1 | acapulco de juarez
# Processing Record 38 of Set 1 | sicuani
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | grytviken
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | touros
# Processing Record 44 of Set 1 | bubaque
# Processing Record 45 of Set 1 | pacasmayo
# Processing Record 46 of Set 1 | talnakh
# Processing Record 47 of Set 1 | thunder bay
# Processing Record 48 of Set 1 | afaahiti
# Processing Record 49 of Set 1 | souq larb'a al gharb
# Processing Record 50 of Set 1 | thompson
# Processing Record 0 of Set 2 | tazovsky
# Processing Record 1 of Set 2 | rhar el melah
# Processing Record 2 of Set 2 | cable beach
# City not found. Skipping...
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | choibalsan
# Processing Record 5 of Set 2 | lautoka
# Processing Record 6 of Set 2 | yuzhno-kurilsk
# Processing Record 7 of Set 2 | tazacorte
# Processing Record 8 of Set 2 | atafu village
# Processing Record 9 of Set 2 | labrador city
# Processing Record 10 of Set 2 | retreat
# Processing Record 11 of Set 2 | kailua-kona
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | isafjordur
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | castanos
# Processing Record 16 of Set 2 | saint-pierre
# Processing Record 17 of Set 2 | am djarass
# City not found. Skipping...
# Processing Record 18 of Set 2 | shingu
# Processing Record 19 of Set 2 | kingston
# Processing Record 20 of Set 2 | aasiaat
# Processing Record 21 of Set 2 | gurupi
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | kantunilkin
# Processing Record 24 of Set 2 | kayangel
# Processing Record 25 of Set 2 | teknaf
# Processing Record 26 of Set 2 | colchani
# Processing Record 27 of Set 2 | zapolyarnyy
# Processing Record 28 of Set 2 | fale old settlement
# Processing Record 29 of Set 2 | mount gambier
# Processing Record 30 of Set 2 | ain beni mathar
# City not found. Skipping...
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | fort st. john
# Processing Record 33 of Set 2 | carolina beach
# Processing Record 34 of Set 2 | reggane
# Processing Record 35 of Set 2 | novodmitriyevskaya
# Processing Record 36 of Set 2 | avellaneda
# Processing Record 37 of Set 2 | portland
# Processing Record 38 of Set 2 | betong
# Processing Record 39 of Set 2 | whitehorse
# Processing Record 40 of Set 2 | guerrero negro
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | iskateley
# Processing Record 43 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 44 of Set 2 | port mathurin
# Processing Record 45 of Set 2 | puerto natales
# Processing Record 46 of Set 2 | west island
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | saipan
# Processing Record 49 of Set 2 | st. john's
# Processing Record 0 of Set 3 | madingou
# Processing Record 1 of Set 3 | queenstown
# Processing Record 2 of Set 3 | kalevala
# Processing Record 3 of Set 3 | emerald
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | awjilah
# Processing Record 6 of Set 3 | saint-joseph
# Processing Record 7 of Set 3 | bereznik
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | qaqortoq
# Processing Record 11 of Set 3 | kolpashevo
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | skagen
# Processing Record 14 of Set 3 | gusinoozyorsk
# Processing Record 15 of Set 3 | utrik
# Processing Record 16 of Set 3 | borzya
# Processing Record 17 of Set 3 | uturoa
# Processing Record 18 of Set 3 | mukalla
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | dabou
# Processing Record 22 of Set 3 | novogrudok
# Processing Record 23 of Set 3 | mandal
# Processing Record 24 of Set 3 | brooks
# Processing Record 25 of Set 3 | loves park
# Processing Record 26 of Set 3 | don sak
# Processing Record 27 of Set 3 | yinchuan
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | moose jaw
# Processing Record 30 of Set 3 | amos
# Processing Record 31 of Set 3 | ambon
# Processing Record 32 of Set 3 | san salvador de jujuy
# Processing Record 33 of Set 3 | lingyuan
# Processing Record 34 of Set 3 | bargara
# City not found. Skipping...
# Processing Record 35 of Set 3 | oromocto
# Processing Record 36 of Set 3 | callao
# Processing Record 37 of Set 3 | kapuskasing
# Processing Record 38 of Set 3 | klimavichy
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | mermoz boabab
# Processing Record 42 of Set 3 | duong dong
# Processing Record 43 of Set 3 | baijiantan
# Processing Record 44 of Set 3 | rongelap
# Processing Record 45 of Set 3 | oneonta
# Processing Record 46 of Set 3 | hermanus
# Processing Record 47 of Set 3 | karratha
# Processing Record 48 of Set 3 | sarykemer
# Processing Record 49 of Set 3 | huejutla de reyes
# Processing Record 0 of Set 4 | sinabang
# Processing Record 1 of Set 4 | conceicao da barra
# Processing Record 2 of Set 4 | maceio
# Processing Record 3 of Set 4 | nguigmi
# Processing Record 4 of Set 4 | seversk
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | gizycko
# Processing Record 7 of Set 4 | la passe
# Processing Record 8 of Set 4 | lihue
# Processing Record 9 of Set 4 | kermit
# Processing Record 10 of Set 4 | veinticinco de mayo
# Processing Record 11 of Set 4 | ust-nera
# Processing Record 12 of Set 4 | dunedin
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | nabire
# Processing Record 15 of Set 4 | isiro
# Processing Record 16 of Set 4 | klyuchi
# Processing Record 17 of Set 4 | collie
# Processing Record 18 of Set 4 | tuytepa
# Processing Record 19 of Set 4 | salinopolis
# Processing Record 20 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 21 of Set 4 | nova sintra
# Processing Record 22 of Set 4 | chebba
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | sodankyla
# Processing Record 25 of Set 4 | kidal
# Processing Record 26 of Set 4 | yerofey pavlovich
# Processing Record 27 of Set 4 | wailua homesteads
# Processing Record 28 of Set 4 | egersund
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | bayan nur
# City not found. Skipping...
# Processing Record 31 of Set 4 | puerto san jose
# Processing Record 32 of Set 4 | nuuk
# Processing Record 33 of Set 4 | shizuishan
# Processing Record 34 of Set 4 | dzhalagash
# Processing Record 35 of Set 4 | chibougamau
# Processing Record 36 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | makhambet
# Processing Record 40 of Set 4 | gadzhiyevo
# Processing Record 41 of Set 4 | udachny
# Processing Record 42 of Set 4 | gamba
# Processing Record 43 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 44 of Set 4 | deblin
# Processing Record 45 of Set 4 | cadale
# Processing Record 46 of Set 4 | bridgetown
# Processing Record 47 of Set 4 | coaldale
# Processing Record 48 of Set 4 | susuman
# Processing Record 49 of Set 4 | olyokminsk
# Processing Record 0 of Set 5 | severobaykal'sk
# Processing Record 1 of Set 5 | saint-philippe
# Processing Record 2 of Set 5 | mbuji-mayi
# Processing Record 3 of Set 5 | kostroma
# Processing Record 4 of Set 5 | forster
# Processing Record 5 of Set 5 | port alfred
# Processing Record 6 of Set 5 | island harbour
# Processing Record 7 of Set 5 | vorgashor
# Processing Record 8 of Set 5 | champerico
# Processing Record 9 of Set 5 | broome
# Processing Record 10 of Set 5 | paka
# Processing Record 11 of Set 5 | kudahuvadhoo
# Processing Record 12 of Set 5 | lampang
# Processing Record 13 of Set 5 | geraldton
# Processing Record 14 of Set 5 | rakops
# Processing Record 15 of Set 5 | dudinka
# Processing Record 16 of Set 5 | chimoio
# Processing Record 17 of Set 5 | holualoa
# Processing Record 18 of Set 5 | yelizovo
# Processing Record 19 of Set 5 | palikir - national government center
# Processing Record 20 of Set 5 | altai
# Processing Record 21 of Set 5 | dajal
# Processing Record 22 of Set 5 | berdigestyakh
# Processing Record 23 of Set 5 | hawaiian paradise park
# Processing Record 24 of Set 5 | chernyshevsk
# Processing Record 25 of Set 5 | jalai nur
# Processing Record 26 of Set 5 | i-n-salah
# Processing Record 27 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 28 of Set 5 | antofagasta
# Processing Record 29 of Set 5 | axim
# Processing Record 30 of Set 5 | lubao
# Processing Record 31 of Set 5 | pozzallo
# Processing Record 32 of Set 5 | nar'yan-mar
# Processing Record 33 of Set 5 | at taj
# Processing Record 34 of Set 5 | severo-yeniseyskiy
# Processing Record 35 of Set 5 | augustow
# Processing Record 36 of Set 5 | alice springs
# Processing Record 37 of Set 5 | kapa'a
# Processing Record 38 of Set 5 | lazaro cardenas
# Processing Record 39 of Set 5 | dolinsk
# Processing Record 40 of Set 5 | las rosas
# Processing Record 41 of Set 5 | dongola
# Processing Record 42 of Set 5 | ijuw
# City not found. Skipping...
# Processing Record 43 of Set 5 | fomboni
# Processing Record 44 of Set 5 | santa ana
# Processing Record 45 of Set 5 | cururupu
# Processing Record 46 of Set 5 | el fasher
# Processing Record 47 of Set 5 | tralee
# Processing Record 48 of Set 5 | lerwick
# Processing Record 49 of Set 5 | saudarkrokur
# Processing Record 0 of Set 6 | sandnessjoen
# Processing Record 1 of Set 6 | songyang
# Processing Record 2 of Set 6 | kaiyuan
# Processing Record 3 of Set 6 | armacao de buzios
# Processing Record 4 of Set 6 | nadym
# Processing Record 5 of Set 6 | ain beida
# Processing Record 6 of Set 6 | mana
# Processing Record 7 of Set 6 | selfoss
# Processing Record 8 of Set 6 | whakatane
# Processing Record 9 of Set 6 | dwarka
# Processing Record 10 of Set 6 | flying fish cove
# Processing Record 11 of Set 6 | nelson bay
# Processing Record 12 of Set 6 | nizhnesortymskiy
# Processing Record 13 of Set 6 | fuli
# Processing Record 14 of Set 6 | camana
# Processing Record 15 of Set 6 | el granada
# Processing Record 16 of Set 6 | praia da vitoria
# Processing Record 17 of Set 6 | bardai
# Processing Record 18 of Set 6 | kourou
# Processing Record 19 of Set 6 | badger
# Processing Record 20 of Set 6 | lebu
# Processing Record 21 of Set 6 | fayroz koh
# Processing Record 22 of Set 6 | ejido benito juarez
# City not found. Skipping...
# Processing Record 23 of Set 6 | gudalur
# Processing Record 24 of Set 6 | vilyuysk
# Processing Record 25 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 26 of Set 6 | dzhetygara
# Processing Record 27 of Set 6 | crane
# Processing Record 28 of Set 6 | kerikeri
# Processing Record 29 of Set 6 | caras
# Processing Record 30 of Set 6 | ugoofaaru
# Processing Record 31 of Set 6 | concepcion
# Processing Record 32 of Set 6 | cankuzo
# Processing Record 33 of Set 6 | ancud
# Processing Record 34 of Set 6 | kavieng
# Processing Record 35 of Set 6 | berdyansk
# Processing Record 36 of Set 6 | revda
# Processing Record 37 of Set 6 | new norfolk
# Processing Record 38 of Set 6 | san antonio de pale
# Processing Record 39 of Set 6 | ola
# Processing Record 40 of Set 6 | selibaby
# Processing Record 41 of Set 6 | lata
# Processing Record 42 of Set 6 | prieska
# Processing Record 43 of Set 6 | isangel
# Processing Record 44 of Set 6 | pisco
# Processing Record 45 of Set 6 | kil'mez'
# City not found. Skipping...
# Processing Record 46 of Set 6 | margate
# Processing Record 47 of Set 6 | mugango
# Processing Record 48 of Set 6 | coronel suarez
# Processing Record 49 of Set 6 | vadso
# Processing Record 0 of Set 7 | kavalerovo
# Processing Record 1 of Set 7 | buka
# Processing Record 2 of Set 7 | haiku-pauwela
# Processing Record 3 of Set 7 | irymple
# Processing Record 4 of Set 7 | antonio enes
# Processing Record 5 of Set 7 | chonchi
# Processing Record 6 of Set 7 | swift current
# Processing Record 7 of Set 7 | cox's bazar
# Processing Record 8 of Set 7 | weno
# Processing Record 9 of Set 7 | rosario oeste
# Processing Record 10 of Set 7 | antigonish
# Processing Record 11 of Set 7 | thinadhoo
# Processing Record 12 of Set 7 | magadan
# Processing Record 13 of Set 7 | ciudad valles
# Processing Record 14 of Set 7 | marudi
# City not found. Skipping...
# Processing Record 15 of Set 7 | zhob
# Processing Record 16 of Set 7 | beloyarskiy
# Processing Record 17 of Set 7 | santa rosa de osos
# Processing Record 18 of Set 7 | fort saskatchewan
# Processing Record 19 of Set 7 | koundara
# Processing Record 20 of Set 7 | alesund
# Processing Record 21 of Set 7 | akdepe
# Processing Record 22 of Set 7 | pagar alam
# Processing Record 23 of Set 7 | mount isa
# Processing Record 24 of Set 7 | miramichi
# Processing Record 25 of Set 7 | sade
# Processing Record 26 of Set 7 | keflavik
# Processing Record 27 of Set 7 | svetlyy
# Processing Record 28 of Set 7 | ambatondrazaka
# Processing Record 29 of Set 7 | almeirim
# Processing Record 30 of Set 7 | heilbron
# Processing Record 31 of Set 7 | buala
# Processing Record 32 of Set 7 | auki
# Processing Record 33 of Set 7 | parras de la fuente
# Processing Record 34 of Set 7 | lillesand
# Processing Record 35 of Set 7 | kinablangan
# Processing Record 36 of Set 7 | kharkhorin
# Processing Record 37 of Set 7 | rodolfo sanchez taboada
# Processing Record 38 of Set 7 | sao jose da coroa grande
# Processing Record 39 of Set 7 | ornskoldsvik
# Processing Record 40 of Set 7 | mtwara
# Processing Record 41 of Set 7 | vernon
# Processing Record 42 of Set 7 | port macquarie
# Processing Record 43 of Set 7 | agat village
# Processing Record 44 of Set 7 | kombissiri
# Processing Record 45 of Set 7 | zungeru
# Processing Record 46 of Set 7 | tosontsengel
# Processing Record 47 of Set 7 | qujing
# Processing Record 48 of Set 7 | smithers
# Processing Record 49 of Set 7 | prince rupert
# Processing Record 0 of Set 8 | margaret river
# Processing Record 1 of Set 8 | sao raimundo das mangabeiras
# Processing Record 2 of Set 8 | meadow lakes
# Processing Record 3 of Set 8 | chopda
# Processing Record 4 of Set 8 | polyarnyy
# Processing Record 5 of Set 8 | alaghsas
# Processing Record 6 of Set 8 | poronaysk
# Processing Record 7 of Set 8 | aykhal
# Processing Record 8 of Set 8 | remire-montjoly
# Processing Record 9 of Set 8 | puerto baquerizo moreno
# Processing Record 10 of Set 8 | codrington
# Processing Record 11 of Set 8 | kuala terengganu
# Processing Record 12 of Set 8 | tofol
# Processing Record 13 of Set 8 | galliano
# Processing Record 14 of Set 8 | mount pearl
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | hanceville
# Processing Record 17 of Set 8 | wellington
# Processing Record 18 of Set 8 | huarmey
# Processing Record 19 of Set 8 | neiafu
# Processing Record 20 of Set 8 | port glaud
# City not found. Skipping...
# Processing Record 21 of Set 8 | princeton
# Processing Record 22 of Set 8 | sierra grande
# Processing Record 23 of Set 8 | fonadhoo
# City not found. Skipping...
# Processing Record 24 of Set 8 | sitka
# Processing Record 25 of Set 8 | minot
# Processing Record 26 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 27 of Set 8 | san andres
# Processing Record 28 of Set 8 | gizo
# Processing Record 29 of Set 8 | puerto deseado
# Processing Record 30 of Set 8 | gorontalo
# Processing Record 31 of Set 8 | summit park
# Processing Record 32 of Set 8 | cody
# Processing Record 33 of Set 8 | tonj
# Processing Record 34 of Set 8 | taroa
# Processing Record 35 of Set 8 | hell-ville
# Processing Record 36 of Set 8 | port lincoln
# Processing Record 37 of Set 8 | enewetak
# Processing Record 38 of Set 8 | ambovombe
# Processing Record 39 of Set 8 | gamboma
# Processing Record 40 of Set 8 | vanimo
# Processing Record 41 of Set 8 | pangai
# Processing Record 42 of Set 8 | edd
# Processing Record 43 of Set 8 | greenland
# Processing Record 44 of Set 8 | fort mcmurray
# Processing Record 45 of Set 8 | hami
# Processing Record 46 of Set 8 | sao joao da barra
# Processing Record 47 of Set 8 | sisimiut
# Processing Record 48 of Set 8 | atbasar
# Processing Record 49 of Set 8 | greymouth
# Processing Record 0 of Set 9 | salekhard
# Processing Record 1 of Set 9 | cockburn town
# Processing Record 2 of Set 9 | dukhan
# Processing Record 3 of Set 9 | hakui
# Processing Record 4 of Set 9 | san luis de la loma
# Processing Record 5 of Set 9 | sakaraha
# Processing Record 6 of Set 9 | safford
# Processing Record 7 of Set 9 | pibor
# City not found. Skipping...
# Processing Record 8 of Set 9 | nazca
# Processing Record 9 of Set 9 | heinola
# Processing Record 10 of Set 9 | solnechnyy
# Processing Record 11 of Set 9 | kolonia town
# Processing Record 12 of Set 9 | yemetsk
# Processing Record 13 of Set 9 | kongolo
# Processing Record 14 of Set 9 | sinan
# Processing Record 15 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 16 of Set 9 | cidreira
# Processing Record 17 of Set 9 | kolwezi
# Processing Record 18 of Set 9 | akrehamn
# Processing Record 19 of Set 9 | shevchenko
# Processing Record 20 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 21 of Set 9 | la ronge
# Processing Record 22 of Set 9 | ceeldheer
# Processing Record 23 of Set 9 | el calafate
# Processing Record 24 of Set 9 | okhotsk
# Processing Record 25 of Set 9 | novyy urengoy
# Processing Record 26 of Set 9 | mili
# Processing Record 27 of Set 9 | keila
# Processing Record 28 of Set 9 | beni
# Processing Record 29 of Set 9 | belo sur tsiribihina
# Processing Record 30 of Set 9 | ulanhot
# Processing Record 31 of Set 9 | aykol
# City not found. Skipping...
# Processing Record 32 of Set 9 | malanje
# Processing Record 33 of Set 9 | baihe
# Processing Record 34 of Set 9 | cabedelo
# Processing Record 35 of Set 9 | carbonear
# Processing Record 36 of Set 9 | manokwari
# Processing Record 37 of Set 9 | khovd
# Processing Record 38 of Set 9 | nogliki
# Processing Record 39 of Set 9 | anadyr
# Processing Record 40 of Set 9 | vilyuchinsk
# Processing Record 41 of Set 9 | salalah
# Processing Record 42 of Set 9 | gagliano del capo
# Processing Record 43 of Set 9 | northam
# Processing Record 44 of Set 9 | mariental
# Processing Record 45 of Set 9 | mairi
# Processing Record 46 of Set 9 | egilsstadir
# Processing Record 47 of Set 9 | inhambane
# Processing Record 48 of Set 9 | ulladulla
# Processing Record 49 of Set 9 | hoxtolgay
# City not found. Skipping...
# Processing Record 0 of Set 10 | hadibu
# Processing Record 1 of Set 10 | mersa matruh
# Processing Record 2 of Set 10 | timra
# Processing Record 3 of Set 10 | rensselaer
# Processing Record 4 of Set 10 | n'zeto
# Processing Record 5 of Set 10 | giado
# Processing Record 6 of Set 10 | paita
# Processing Record 7 of Set 10 | saiha
# Processing Record 8 of Set 10 | linden
# Processing Record 9 of Set 10 | saint-tropez
# Processing Record 10 of Set 10 | ulsteinvik
# Processing Record 11 of Set 10 | changyon
# Processing Record 12 of Set 10 | grande prairie
# Processing Record 13 of Set 10 | mirnyy
# Processing Record 14 of Set 10 | dongcun
# Processing Record 15 of Set 10 | bikenibeu village
# Processing Record 16 of Set 10 | oltiariq
# Processing Record 17 of Set 10 | valparaiso
# Processing Record 18 of Set 10 | orkney
# Processing Record 19 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 20 of Set 10 | brookings
# Processing Record 21 of Set 10 | sao gabriel da cachoeira
# Processing Record 22 of Set 10 | parauapebas
# Processing Record 23 of Set 10 | rawson
# Processing Record 24 of Set 10 | thai nguyen
# Processing Record 25 of Set 10 | songjianghe
# Processing Record 26 of Set 10 | wenling
# Processing Record 27 of Set 10 | freetown
# Processing Record 28 of Set 10 | balykshi
# Processing Record 29 of Set 10 | abong mbang
# Processing Record 30 of Set 10 | tame
# Processing Record 31 of Set 10 | qamdo
# Processing Record 32 of Set 10 | sungailiat
# Processing Record 33 of Set 10 | nurota
# Processing Record 34 of Set 10 | muroto-misakicho
# Processing Record 35 of Set 10 | childress
# Processing Record 36 of Set 10 | abdurahmoni jomi
# Processing Record 37 of Set 10 | saint croix
# Processing Record 38 of Set 10 | ingeniero guillermo n. juarez
# Processing Record 39 of Set 10 | scone
# Processing Record 40 of Set 10 | punta del este
# Processing Record 41 of Set 10 | jinchang
# Processing Record 42 of Set 10 | galle
# Processing Record 43 of Set 10 | tarawa
# Processing Record 44 of Set 10 | al ghayzah
# Processing Record 45 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 46 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 47 of Set 10 | sault ste. marie
# Processing Record 48 of Set 10 | nantucket
# Processing Record 49 of Set 10 | bamberg
# Processing Record 0 of Set 11 | angra do heroismo
# Processing Record 1 of Set 11 | abepura
# Processing Record 2 of Set 11 | pangody
# Processing Record 3 of Set 11 | moussoro
# Processing Record 4 of Set 11 | ust'-uda
# Processing Record 5 of Set 11 | mikuni
# Processing Record 6 of Set 11 | atherton
# Processing Record 7 of Set 11 | santa ana de yacuma
# Processing Record 8 of Set 11 | redencao
# Processing Record 9 of Set 11 | khorugh
# Processing Record 10 of Set 11 | were ilu
# Processing Record 11 of Set 11 | lianjiang
# Processing Record 12 of Set 11 | itoman
# Processing Record 13 of Set 11 | tchintabaraden
# Processing Record 14 of Set 11 | nushki
# Processing Record 15 of Set 11 | canavieiras
# Processing Record 16 of Set 11 | coquimbo
# Processing Record 17 of Set 11 | marsaskala
# City not found. Skipping...
# Processing Record 18 of Set 11 | alofi
# Processing Record 19 of Set 11 | midvagur
# Processing Record 20 of Set 11 | cacu
# Processing Record 21 of Set 11 | sinop
# Processing Record 22 of Set 11 | kroya
# Processing Record 23 of Set 11 | manggar
# Processing Record 24 of Set 11 | kondopoga
# Processing Record 25 of Set 11 | sabha
# Processing Record 26 of Set 11 | goba
# Processing Record 27 of Set 11 | kencong
# Processing Record 28 of Set 11 | flin flon
# Processing Record 29 of Set 11 | roses
# Processing Record 30 of Set 11 | iaciara
# Processing Record 31 of Set 11 | mangrol
# Processing Record 32 of Set 11 | feodosiya
# Processing Record 33 of Set 11 | sabaneta
# Processing Record 34 of Set 11 | nemuro
# Processing Record 35 of Set 11 | usogorsk
# Processing Record 36 of Set 11 | turbat
# Processing Record 37 of Set 11 | pariaman
# Processing Record 38 of Set 11 | trondheim
# Processing Record 39 of Set 11 | calama
# Processing Record 40 of Set 11 | nahavand
# Processing Record 41 of Set 11 | gold camp
# Processing Record 42 of Set 11 | ballina
# Processing Record 43 of Set 11 | mahibadhoo
# Processing Record 44 of Set 11 | bijar
# Processing Record 45 of Set 11 | laguna
# Processing Record 46 of Set 11 | rechka-vydrino
# Processing Record 47 of Set 11 | san vicente de chucuri
# Processing Record 48 of Set 11 | fada
# Processing Record 49 of Set 11 | najran
# Processing Record 0 of Set 12 | ahmadpur east
# Processing Record 1 of Set 12 | sur
# Processing Record 2 of Set 12 | saint-francois
# Processing Record 3 of Set 12 | oranjemund
# Processing Record 4 of Set 12 | ha'il
# Processing Record 5 of Set 12 | howard springs
# Processing Record 6 of Set 12 | belyy yar
# Processing Record 7 of Set 12 | naze
# Processing Record 8 of Set 12 | mugia
# Processing Record 9 of Set 12 | kutum
# Processing Record 10 of Set 12 | othello
# Processing Record 11 of Set 12 | luorong
# Processing Record 12 of Set 12 | taoudenni
# Processing Record 13 of Set 12 | minas de marcona
# Processing Record 14 of Set 12 | savanna-la-mar
# Processing Record 15 of Set 12 | corumba
# Processing Record 16 of Set 12 | zhangye
# Processing Record 17 of Set 12 | mejit
# Processing Record 18 of Set 12 | acarau
# Processing Record 19 of Set 12 | geroskipou
# City not found. Skipping...
# Processing Record 20 of Set 12 | itamaraca
# Processing Record 21 of Set 12 | gilgit
# Processing Record 22 of Set 12 | izberbash
# Processing Record 23 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 24 of Set 12 | kitimat
# Processing Record 25 of Set 12 | kauhava
# Processing Record 26 of Set 12 | atambua
# Processing Record 27 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 12 | gogrial
# Processing Record 29 of Set 12 | usinsk
# Processing Record 30 of Set 12 | morehead city
# Processing Record 31 of Set 12 | cerro azul
# Processing Record 32 of Set 12 | huanuco
# Processing Record 33 of Set 12 | caconda
# Processing Record 34 of Set 12 | goondiwindi
# Processing Record 35 of Set 12 | yasuj
# Processing Record 36 of Set 12 | miches
# Processing Record 37 of Set 12 | asau village
# City not found. Skipping...
# Processing Record 38 of Set 12 | kuanda
# Processing Record 39 of Set 12 | santa helena
# Processing Record 40 of Set 12 | petrolina
# Processing Record 41 of Set 12 | basco
# Processing Record 42 of Set 12 | kismayo
# Processing Record 43 of Set 12 | poptun
# Processing Record 44 of Set 12 | san fernando
# Processing Record 45 of Set 12 | kegen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167    276.91        96         100
# 1             kodiak  57.7900 -152.4072    279.88       100         100
# 2           bilibino  68.0546  166.4372    282.55        66         100
# 3             nicoya  10.1483  -85.4520    303.23        70          86
# 4           waitangi -43.9535 -176.5597    283.05        97         100
#
#    Wind Speed Country        Date
# 0       21.45      TF  1718037999
# 1        7.20      US  1718038135
# 2        1.26      RU  1718038039
# 3        1.09      CR  1718038285
# 4        0.45      NZ  1718037994

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    276.91        96         100
# 1                   kodiak  57.7900 -152.4072    279.88       100         100
# 2                 bilibino  68.0546  166.4372    282.55        66         100
# 3                   nicoya  10.1483  -85.4520    303.23        70          86
# 4                 waitangi -43.9535 -176.5597    283.05        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0             21.45      TF  1718037999
# 1              7.20      US  1718038135
# 2              1.26      RU  1718038039
# 3              1.09      CR  1718038285
# 4              0.45      NZ  1718037994

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.80, edgecolors = "k", linewidths = 1)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("City Latitude vs Temperature")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.80, edgecolors = "k", linewidths = 1)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("City Latitude vs Humidity")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.80, edgecolors = "k", linewidths = 1)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'City Latitude vs Cloudiness')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.80, edgecolors = "k", linewidths = 1)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'City Latitude vs Wind Speed')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lineregress(x,y):
    slope, intercept, rvalue, p_value, std_err =linregress(x, y)
    plt.plot(x, [intercept + slope*val for val in x], 'r')
    print(f"The R-squared is: [rvalue]")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              kodiak  57.7900 -152.4072    279.88       100         100
# 2            bilibino  68.0546  166.4372    282.55        66         100
# 3              nicoya  10.1483  -85.4520    303.23        70          86
# 5        san patricio  28.0170  -97.5169    307.09        47          25
# 6             iqaluit  63.7506  -68.5145    276.00        60          75
#
#          Wind Speed Country        Date
# City_ID
# 1              7.20      US  1718038135
# 2              1.26      RU  1718038039
# 3              1.09      CR  1718038285
# 5              1.92      US  1718038096
# 6              2.57      CA  1718037991

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    276.91        96         100
# 4                 waitangi -43.9535 -176.5597    283.05        97         100
# 7                adamstown -25.0660 -130.1015    295.81        81          97
# 9                 tolanaro -25.0319   46.9987    292.19        77          75
# 14               bel ombre  -4.6167   55.4167    301.06        78          20
#
#          Wind Speed Country        Date
# City_ID
# 0             21.45      TF  1718037999
# 4              0.45      NZ  1718037994
# 7              7.97      PN  1718038287
# 9              7.20      MG  1718038287
# 14             2.06      SC  1718038289

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lineregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
slope, intercept, rvalue, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df["Max Temp"])
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
slope = '{0:.2f}'.format(slope)
intercept = '{0:,.2f}'.format(intercept)

plt.text(0,272, s=f"y = {slope}x + {intercept}", c='r', size='x-large')
plt.ylabel("Max Temp")
plt.xlabel("Latitude")
plt.savefig("output_data/north_max_temp.png")
# Out:
# The R-squared is: [rvalue]

# %%
# Linear regression on Southern Hemisphere
lineregress(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
slope, intercept, rvalue, p_value, std_err =linregress(southern_hemi_df['Lat'], southern_hemi_df["Max Temp"])
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
slope = '{0:,.2f}'.format(slope)
intercept = '{0:,.2f}'.format(intercept)

plt.text(-50,272, s=f"y = {slope}x + {intercept}", c='r', size='x-large')
plt.ylabel("Max Temp")
plt.xlabel("Latitude")
plt.savefig("output_data/south_max_temp.png")
# Out:
# The R-squared is: [rvalue]

# %% [markdown]
# **Discussion about the linear relationship: ** The Northern Hemisphere has a negative correlation between latitude and max temperature. The temperature tends to decrease, moving towards the north. In the Southern Hemisphere, a positive correlation is moving farther from the south pole (higher x-values), and the max temperature tends to increase. The intercept on the northern and southern hemispheres suggests the expected maximum temperature at the equator (where x = 0).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lineregress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
slope, intercept, rvalue, p_value, std_err =linregress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
slope = '{0:,.2f}'.format(slope)
intercept = '{0:,.2f}'.format(intercept)

plt.text(50,10, s=f"y = {slope}x + {intercept}", c='r', size='x-large')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.savefig("output_data/north_humidity.png")
# Out:
# The R-squared is: [rvalue]

# %%
# Southern Hemisphere
lineregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
slope, intercept, rvalue, p_value, std_err =linregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
slope = '{0:,.2f}'.format(slope)
intercept = '{0:,.2f}'.format(intercept)

plt.text(-55,20, s=f"y = {slope}x + {intercept}", c='r', size='x-large')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.savefig("output_data/south_humidity.png")
# Out:
# The R-squared is: [rvalue]

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere, the positive correlation indicates that there is an overall increasing trend of humidity with increasing latitude. However, given the relatively small slope, this increase is gradual.
# In the Southern Hemisphere, there is a slight negative linear relationship between latitude and humidity. As the latitude increases (moving away from the equator towards the poles), the humidity tends to decrease.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lineregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
slope, intercept, rvalue, p_value, std_err =linregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
slope = '{0:,.2f}'.format(slope)
intercept = '{0:,.2f}'.format(intercept)

plt.text(0,10, s=f"y = {slope}x + {intercept}", c='r', size='x-large')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.savefig("output_data/north_cloudiness.png")
# Out:
# The R-squared is: [rvalue]

# %%
# Southern Hemisphere
lineregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
slope, intercept, rvalue, p_value, std_err =linregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
slope = '{0:,.2f}'.format(slope)
intercept = '{0:,.2f}'.format(intercept)

plt.text(-57,0, s=f"y = {slope}x + {intercept}", c='r', size='x-large')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.savefig("output_data/south_cloudiness.png")
# Out:
# The R-squared is: [rvalue]

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere, the linear model does not fully  capture the correlation between latitude and cloudiness. Furthermore, the spread of data points and the concentration at the extremes imply that the variability in cloudiness is higher at certain latitudes (perhaps near the poles and the Equator) and lower at mid-latitudes. This might be due to different climatic zones experiencing different cloud formation patterns. Moreover, The concentration at the top and bottom might indicate the presence of clusters or outliers in the data. These clusters could be regions where cloudiness is consistently high or low, potentially due to specific climatic conditions or geographical features influencing cloud formation.
# In the Southern Hemisphere, the correlation between cloudiness and latitude is negative. There is a decrease in cloudiness with increasing latitude, the data points indicate significant variability and higher-than-predicted cloudiness, particularly closer to the Equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lineregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
slope, intercept, rvalue, p_value, std_err =linregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
slope = '{0:,.2f}'.format(slope)
intercept = '{0:,.2f}'.format(intercept)

plt.text(0,-3, s=f"y = {slope}x + {intercept}", c='r', size='x-large')
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.savefig("output_data/north_wind_speed.png")
# Out:
# The R-squared is: [rvalue]

# %%
# Southern Hemisphere
lineregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
slope, intercept, rvalue, p_value, std_err =linregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
slope = '{0:,.2f}'.format(slope)
intercept = '{0:,.2f}'.format(intercept)

plt.text(-55,-3, s=f"y = {slope}x + {intercept}", c='r', size='x-large')
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.savefig("output_data/south_wind_speed.png")
# Out:
# The R-squared is: [rvalue]

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere, there is a slight negative correlation between the wind speed and latitude. The variability in the data indicates that latitude is not a strong determinant of wind speed, and other geographical or environmental factors are likely playing a more significant role.
# In the Southern Hemisphere, the wind speed decreased with increasing latitude but the effect is minimal. The inverse relationship between latitude and wind speed, with most locations experiencing relatively lower wind speeds and some exceptions with higher wind speeds, likely influenced by local geographical factors.
